# %% [markdown]
# <a href="https://colab.research.google.com/github/arpit4101/Machine-Learning-Concepts/blob/main/Regularisation/Ridge/Ridge_regression_from_scratch_class_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=10)
rr.fit(X,y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235735

# %%
from sklearn.linear_model import Ridge

rr1 = Ridge(alpha=50)
rr1.fit(X,y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235735

# %%
from sklearn.linear_model import Ridge

rr2 = Ridge(alpha=100)
rr2.fit(X,y)
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [17.66035643]
# -1.7008737066555062

# %%
import matplotlib.pyplot as plt

plt.scatter(X,y)
plt.plot(X,lr.predict(X), color = 'red', label='Linear Regression')
plt.plot(X,rr.predict(X), color = 'green', label='RR : alpha=10')
plt.plot(X,rr1.predict(X), color = 'green', label='RR : alpha=50')
plt.plot(X, rr2.predict(X), color = 'orange', label = 'RR : alpha=100')
plt.legend()
plt.show()

# %% [markdown]
# # Class code of Linear Regression

# %%
class meralr:

  def __init__(self):

    self.m = None
    self.b = None

  def fit(self, X,y):

    num=0
    den=0

    for i in range(X.shape[0]):

      num = num + ( (y[i]-np.mean(y)) * (X[i] - np.mean(X)))
      den = den + ( X[i] - np.mean(X) )**2

    self.m = num/den
    self.b = np.mean(y) - ( self.m * np.mean(X))

  def predict(self, X):

    return (self.m * X) + self.b

# %%
mlr = meralr()
mlr.fit(X,y)
print(mlr.m)
print(mlr.b)
# Out:
# [27.82809103]
# [-2.29474456]

# %% [markdown]
# # Ridge Regression class code for

# %%
class MeraRidge:

  def __init__(self, alpha = 0.1):

    self.alpha = alpha
    self.coef_ = None
    self.intercept_ = None

  def fit(self, X,y):

    num=0
    den=0

    for i in range(X.shape[0]):

      num = num + ( (y[i] - np.mean(y)) * (X[i] - np.mean(X)) )
      den = den + ( (X[i] - np.mean(X)) ** 2)

    self.coef_ = num / (self.alpha + den)
    self.intercept_ = np.mean(y) - ( self.coef_ * np.mean(X))


  def predict(self, X):

    return (self.coef_ * X) + self.intercept_

# %%
mr = MeraRidge(alpha = 10)

mr.fit(X,y)
print(mr.coef_)
print(mr.intercept_)
# Out:
# [24.9546267]
# [-2.126913]
