# %% [markdown]
# <a href="https://colab.research.google.com/github/arpit4101/Machine-Learning-Concepts/blob/main/Gradient%20Descent/Gradient_Descent_step_by_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import numpy as np

X, y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise = 80, random_state= 13)

# %%
X.shape
# Out:
# (4, 1)

# %%
import matplotlib.pyplot as plt

plt.scatter(X,y)

# %%
#Let's apply OLS to find cofficient(m) & intercept

from sklearn.linear_model import LinearRegression
reg = LinearRegression()

#fitting model
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
print('Coefficient (m) : ', reg.coef_)
print('Intercept (b) : ', reg.intercept_)
# Out:
# Coefficient (m) :  [78.35063668]
# Intercept (b) :  26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color = 'red')

# %%
# Lets apply Gradient Descent assuming slope is constant m = 78.35
# and let's assume the starting value for intercept b = 0
m = 78.35063668
b = 0
y_pred = ((m * X.ravel()) + b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color = 'red', label = 'OLS')
plt.plot(X,y_pred, color = 'blue', label = 'b = {}'.format(b))
plt.legend()

# %% [markdown]
# # Iterating the below steps

# %%
loss_slope = -2 * np.sum(y - (m*X.ravel()) - b)
# b(new) = b(old) - learning_rate *(slope)
#setting learning rate = 0.1
lr = 0.1
step_size = lr * loss_slope

# %%
#Calculating new intercept
b = b - step_size
b1 = b

# %%
y_pred1 = (m * X.ravel()) + b

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 2
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-41.855412548917954)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-4.185541254891795)

# %%
b = b - step_size
b2 = b

# %%
y_pred2 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred2,color='#00a65a',label='b = {}'.format(b2))
plt.plot(X,y_pred1,color='#A3E4D7',label='b = {}'.format(b1))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-8.371082509783605)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-0.8371082509783605)

# %%
b = b - step_size
b3 = b

# %%
y_pred3 = ((78.35 * X) + b).reshape(4)

plt.figure(figsize=(10,10))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred3,color='#00a65a',label='b = {}'.format(b3))
plt.plot(X,y_pred2,color='#A3E4D7',label='b = {}'.format(b2))
plt.plot(X,y_pred1,color='#A3E4D7',label='b = {}'.format(b1))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %% [markdown]
# # Code using For loop to make iteration simple

# %%
m = 78.35063668
b = -100            #(starting point)
learning_rate = 0.1

# l_slope = -2 * np.sum(y - (m * X.ravel()) - b)
# step_size = l_slope * learning_rate

epochs = 100   #epochs is number of iterations to be performed

for i in range(epochs) :

  l_slope = -2 * np.sum(y - (m * X.ravel()) - b)
  step_size = l_slope * learning_rate

  b = b - step_size

  y_pred = (m * X.ravel()) + b

  plt.plot(X, y_pred)

plt.scatter(X, reg.predict(X), color = 'red')
